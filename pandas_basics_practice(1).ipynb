# %% [markdown]
# **Consider the following Python dictionary data and Python list labels:**
#
# data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills'],
#         'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4],
#         'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %% [markdown]
# **1. Create a DataFrame birds from this dictionary data which has the index labels.**

# %%
import pandas as pd
import numpy as np
data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills'], 'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4], 'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2], 'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
table= pd.DataFrame(data,index=labels)
table
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %% [markdown]
# **2. Display a summary of the basic information about birds DataFrame and its data.**

# %%
table.describe()
# Out:
#             age     visits
# count  8.000000  10.000000
# mean   4.437500   2.900000
# std    2.007797   0.875595
# min    1.500000   2.000000
# 25%    3.375000   2.000000
# 50%    4.000000   3.000000
# 75%    5.625000   3.750000
# max    8.000000   4.000000

# %% [markdown]
# **3. Print the first 2 rows of the birds dataframe **

# %%
table.iloc[:2]
# Out:
#     birds  age  visits priority
# a  Cranes  3.5       2      yes
# b  Cranes  4.0       4      yes

# %% [markdown]
# **4. Print all the rows with only 'birds' and 'age' columns from the dataframe**

# %%
pd.DataFrame(data,columns=['birds','age'])
# Out:
#         birds  age
# 0      Cranes  3.5
# 1      Cranes  4.0
# 2     plovers  1.5
# 3  spoonbills  NaN
# 4  spoonbills  6.0
# 5      Cranes  3.0
# 6     plovers  5.5
# 7      Cranes  NaN
# 8  spoonbills  8.0
# 9  spoonbills  4.0

# %% [markdown]
# **5. select [2, 3, 7] rows and in columns ['birds', 'age', 'visits']**

# %%
idx= ['c','d','g']
table.iloc[table.index.get_indexer(idx),:3]
# Out:
#         birds  age  visits
# c     plovers  1.5       3
# d  spoonbills  NaN       4
# g     plovers  5.5       2

# %% [markdown]
# **6. select the rows where the number of visits is less than 4**

# %%
print(table[table['visits']<4])
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# c     plovers  1.5       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %% [markdown]
# **7. select the rows with columns ['birds', 'visits'] where the age is missing i.e NaN**

# %%
temp= table[table['age'].isnull()]
temp[['birds', 'visits']]
# Out:
#         birds  visits
# d  spoonbills       4
# h      Cranes       2

# %% [markdown]
# **8. Select the rows where the birds is a Cranes and the age is less than 4**

# %%
table[(table['birds'] == 'Cranes') & (table['age'] < 4)]
# Out:
#     birds  age  visits priority
# a  Cranes  3.5       2      yes
# f  Cranes  3.0       4       no

# %% [markdown]
# **9. Select the rows the age is between 2 and 4(inclusive)**

# %%
table[(table['age']>=2) & (table['age']<=4)]
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# f      Cranes  3.0       4       no
# j  spoonbills  4.0       2       no

# %% [markdown]
# **10. Find the total number of visits of the bird Cranes**

# %%
table[(table['birds'] == 'Cranes') & (table['visits'] > 0)].sum()
# Out:
# birds       CranesCranesCranesCranes
# age                             10.5
# visits                            12
# priority                 yesyesnoyes
# dtype: object

# %% [markdown]
# **11. Calculate the mean age for each different birds in dataframe.**

# %%
table.groupby('birds')['age'].mean()
# Out:
# birds
# Cranes        3.5
# plovers       3.5
# spoonbills    6.0
# Name: age, dtype: float64

# %% [markdown]
# **12. Append a new row 'k' to dataframe with your choice of values for each column. Then delete that row to return the original DataFrame.**

# %%
table.loc['k'] = ['Cranes', 3.5, 3, 'yes']
print(table)
print('------------------------------------')
print(table.drop('k'))
print(table)
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no
# k      Cranes  3.5       3      yes
# ------------------------------------
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# ...

# %% [markdown]
# **13. Find the number of each type of birds in dataframe (Counts)**

# %%
table['birds'].value_counts()
# Out:
# Cranes        5
# spoonbills    4
# plovers       2
# Name: birds, dtype: int64

# %% [markdown]
# **14. Sort dataframe (birds) first by the values in the 'age' in decending order, then by the value in the 'visits' column in ascending order.**

# %%
print(table.sort_values(['age'],axis=0,ascending=[False]))
print('---------------------------------------------------')
print(table.sort_values(['visits'],axis=0,ascending=[True]))
# Out:
#         birds  age  visits priority
# i  spoonbills  8.0       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# b      Cranes  4.0       4      yes
# j  spoonbills  4.0       2       no
# a      Cranes  3.5       2      yes
# k      Cranes  3.5       3      yes
# f      Cranes  3.0       4       no
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# h      Cranes  NaN       2      yes
# ---------------------------------------------------
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# j  spoonbills  4.0       2       no
# c     plovers  1.5       3       no
# e  spoonbills  6.0       3       no
# i  spoonbills  8.0       3       no
# k      Cranes  3.5       3      yes
# b      Cranes  4.0       4      yes
# d  spoonbills  NaN       4      yes
# f      Cranes  3.0       4       no

# %% [markdown]
# **15. Replace the priority column values with'yes' should be 1 and 'no' should be 0**

# %%
table['priority'].map({1:'yes',0:'no'})
table
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      yes
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no
# k      Cranes  3.5       3      yes

# %% [markdown]
# **16. In the 'birds' column, change the 'Cranes' entries to 'trumpeters'.**

# %%
table.birds.map(lambda x: 'trumpeters' if x=='Cranes' else x)
# Out:
# a    trumpeters
# b    trumpeters
# c       plovers
# d    spoonbills
# e    spoonbills
# f    trumpeters
# g       plovers
# h    trumpeters
# i    spoonbills
# j    spoonbills
# k    trumpeters
# Name: birds, dtype: object
